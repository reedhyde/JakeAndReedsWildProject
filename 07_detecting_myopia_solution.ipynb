# %% [markdown]
# <a href="https://colab.research.google.com/github/reedhyde/JakeAndReedsWildProject/blob/main/07_detecting_myopia_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
myopia_df = pd.read_csv('https://static.bc-edx.com/data/dl-1-2/m21/lessons/2/myopia.csv')
myopia_df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
# prompt: Using dataframe myopia_df: history

myopia_df.history()

# %%
len(myopia_df)
# Out:
# 618

# %%
# Remove MYOPIC target from features data
y = myopia_df.MYOPIC.values
X = myopia_df.drop(columns="MYOPIC").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 2.38478018, -0.03927682,  1.72241759, ...,  1.16410064,
#          0.98499379, -0.98925855],
#        [-0.43553457, -1.09849903, -0.71125994, ...,  2.548679  ,
#         -1.01523483,  1.01085808],
#        [-0.43553457, -0.97903787, -0.10652803, ..., -0.34634848,
#          0.98499379,  1.01085808],
#        ...,
#        [-0.43553457,  0.30317843, -0.26877413, ..., -1.10157304,
#         -1.01523483, -0.98925855],
#        [-0.43553457, -0.49322919, -0.85875614, ..., -1.03863766,
#         -1.01523483, -0.98925855],
#        [ 2.38478018, -2.06215226,  1.92891059, ...,  0.78648836,
#         -1.01523483, -0.98925855]])

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=14))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 4ms/step - loss: 0.9703 - accuracy: 0.2441
# Epoch 2/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.7972 - accuracy: 0.3974
# Epoch 3/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6698 - accuracy: 0.5788
# Epoch 4/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5817 - accuracy: 0.7279
# Epoch 5/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5194 - accuracy: 0.8445
# Epoch 6/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.8639
# Epoch 7/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4407 - accuracy: 0.8661
# Epoch 8/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4158 - accuracy: 0.8661
# Epoch 9/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.8683
# Epoch 10/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8683
# Epoch 11/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.8683
# Epoch 12/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3553 - accuracy: 0.8683
# Epoch 13/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8683
# Epoch 14/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8683
# Epoch 15/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3227 - accuracy: 0.8683
# Epoch 16/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3145 - accuracy: 0.8683
# Epoch 17/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3058 - accuracy: 0.8683
# Epoch 18/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2984 - accuracy: 0.8683
# Epoch 19/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2916 - accuracy: 0.8704
# Epoch 20/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2849 - accuracy: 0.8726
# Epoch 21/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2785 - accuracy: 0.8726
# Epoch 22/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.8747
# Epoch 23/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2658 - accuracy: 0.8769
# Epoch 24/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2598 - accuracy: 0.8790
# Epoch 25/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.8812
# Epoch 26/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2482 - accuracy: 0.8812
# Epoch 27/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2430 - accuracy: 0.8855
# Epoch 28/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2369 - accuracy: 0.8898
# Epoch 29/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.8942
# Epoch 30/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2278 - accuracy: 0.9050
# Epoch 31/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2240 - accuracy: 0.9114
# Epoch 32/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2200 - accuracy: 0.9114
# Epoch 33/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2167 - accuracy: 0.9114
# Epoch 34/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2128 - accuracy: 0.9093
# Epoch 35/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2100 - accuracy: 0.9114
# Epoch 36/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2065 - accuracy: 0.9136
# Epoch 37/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2035 - accuracy: 0.9136
# Epoch 38/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2015 - accuracy: 0.9158
# Epoch 39/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.9158
# Epoch 40/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.9136
# Epoch 41/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1932 - accuracy: 0.9158
# Epoch 42/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1914 - accuracy: 0.9179
# Epoch 43/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1891 - accuracy: 0.9201
# Epoch 44/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1869 - accuracy: 0.9222
# Epoch 45/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1846 - accuracy: 0.9244
# Epoch 46/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1829 - accuracy: 0.9244
# Epoch 47/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1812 - accuracy: 0.9244
# Epoch 48/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1793 - accuracy: 0.9266
# Epoch 49/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1778 - accuracy: 0.9266
# Epoch 50/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.9266
# 5/5 - 0s - loss: 0.4169 - accuracy: 0.8710 - 162ms/epoch - 32ms/step
# Loss: 0.41687849164009094, Accuracy: 0.8709677457809448

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Bootcamp/uber_binned.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226138 entries, 0 to 226137
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            226138 non-null  int64
#  1   ID                    226138 non-null  int64
#  2   hvfhs_license_num     226138 non-null  object
#  3   dispatching_base_num  226138 non-null  object
#  4   pickup_datetime       226138 non-null  object
#  5   dropoff_datetime      226138 non-null  object
#  6   PULocationID          226138 non-null  int64
#  7   DOLocationID          226138 non-null  int64
#  8   pickup_date           226138 non-null  object
#  9   pickup_time           226138 non-null  object
#  10  dropoff_date          226138 non-null  object
#  11  dropoff_time          226138 non-null  object
#  12  Zone                  226138 non-null  object
#  13  Lat                   226138 non-null  float64
#  14  Long                  226138 non-null  float64
#  15  Ride Duration         226138 non-null  object
#  16  bins                  226138 non-null  object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 29.3+ MB
